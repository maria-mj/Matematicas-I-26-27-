# %% [markdown]
# # ✏️ **Nombre y Apellidos:** [ESCRIBE AQUÍ TU NOMBRE]

# %% [markdown]
# # Práctica 1: Introducción a Python para Cálculo
# **Asignatura:** Matemáticas I
#
# **Grado:** Ingeniería y Gestión Empresarial
#
# **Entorno:** Google Colab / Jupyter Notebook
#
# ---

# %% [markdown]
# ## Bloque 1: Python como calculadora básica
# En este primer bloque aprenderemos a ejecutar operaciones aritméticas elementales y a trabajar con asignación de variables.

# %% [markdown]
# **Operaciones aritméticas básicas**

# %%
2+3*4      # Respeta la jerarquía de operaciones

# %%
(2+3)*4    # Uso de paréntesis

# %%
10/3         # División real (devuelve float-decimal)

# %%
10//3        # División entera (cociente)

# %%
10%3         # Módulo (resto de la división)

# %%
2**3         # Potencia (2 elevado a 3) -> ¡Atención: NO usar ^!

# %%
16**0.5      # Raíz cuadrada "rápida"

# %% [markdown]
# **Asignación de variables**

# %%
# Podemos "guardar" valores dándoles un nombre
base = 5
altura = 10
area_triangulo = (base*altura) / 2
print("El área es:", area_triangulo)

# %% [markdown]
# > ⚠️ **Atención - Errores habituales a evitar:**
# > 1. No omitir el signo `*` en las multiplicaciones (escribir `2*x`, nunca `2x`).
# > 2. El operador `^` en Python es XOR bit a bit. Para calcular potencias usa siempre `**`.
# > 3. Recuerda que la división `/` siempre devuelve un número decimal (`float`).

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Obtén el resto de dividir el día de tu cumpleaños elevado al mes, entre tu añuo de nacimiento.

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Define la variable `temp\_c = 25 `(grados Celsius) y calcula en nuevas variables su equivalente en Fahrenheit ($F = \frac{9}{5}C + 32$) y Kelvin ($K = C + 273.15$). Muestra los resultados por pantalla.

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# ## Bloque 2: Operaciones Matemáticas Avanzadas con `sympy`
# En este bloque utilizaremos la librería de cálculo simbólico **SymPy** para definir funciones, obtener valores exactos y resolver límites, derivadas e integrales de manera analítica.

# %%
# Importar paquetes de matemáticas
import sympy as sp

# %%
# Definimos la variable simbólica 'x'
x = sp.Symbol("x")

# %%
# 1. Definición de una función simbólica f(x) = x^2*sin(x)
f = x**2*sp.sin(x)
print("Función f(x) =", f)

# %%
# 2. Evaluación exacta y numérica (.subs y .evalf)
val_exacto = f.subs(x, sp.pi / 2)
val_numerico = val_exacto.evalf()

print("f(pi/2) exacto:", val_exacto)
print("f(pi/2) numérico aprox.:", val_numerico)

## Aproximación de decimales (redondeo)
val_aprx = val_exacto.evalf(3)

print("f(pi/2) aproximado a 3 cifras:", val_aprx)

# %%
# 3. Cálculo de Límites (sp.limit)
g = (1-sp.cos(x))/x**2
limite_0 = sp.limit(g,x,0)

print("Límite de (1-cos(x))/x^2 cuando x->0:", limite_0)

## Límites laterales
lim_der = sp.limit(g,x,0,"+")
lim_izq = sp.limit(g,x,0,"-")

print("Límite cuando x->0+:", lim_der)
print("Límite cuando x->0-:", lim_izq)

# %%
# 4. Cálculo de Derivadas (sp.diff)
df = sp.diff(f,x)
d5f = sp.diff(f,x,5)

print("Primera derivada f'(x) =", df)
print("Quinta derivada f^(5)(x) =", d5f)

# %%
# 5. Integrales Indefinidas y Definidas (sp.integrate)
int_indef = sp.integrate(sp.sin(x),x)
int_def = sp.integrate(x**2,(x,0,3))

print("Integral indefinida de sin(x):", int_indef)
print("Integral definida de x^2 entre 0 y 3:", int_def)

# %% [markdown]
# > ⚠️ **Algunas instrucciones o elementos matemáticos que debemos conocer son:**
# >
# >  1. Infinito: sp.oo
# > 2. Funciones trigonométricas: sp.sin(x), sp.cos(x), sp.tan(x)
# > 3. Función exponencial: sp.exp(x) (el número $e$ sería sp.exp(1))
# > 4. Función logaritmo neperiano: sp.ln(x), sp.log(x)
# > 5. Raíz cuadrada: sp.sqrt(x)

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Define la función $f(x) = e^{-x} \cos(x)$ y calcula el valor de su primera derivada en $x = 0$.

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Calcula el límite $\lim\limits_{x \to 0} \frac{e^x - 1}{x}$. ¿Qué ocurre si intentamos evaluar la función directamente en $x = 0$?

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Calcula los límites de la función $g(x) = 3 \sin(x^2)$ en $\pm \infty$. ¿Cómo interpretas ese resultado?

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# 📝 **Prueba tú**:
#
# *   Calcula la integral indefinida de la función $h(x) = x \cdot e^x$ y, a continuación, halla su integral definida en el intervalo $[0, 1]$.

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# ## Bloque 3: Representación Gráfica de Funciones con `matplotlib`
# En este tercer bloque crearemos rangos (vectores) de números con **NumPy** y los usaremos para graficar funciones con **Matplotlib**.

# %%
# Importamos los paquetes necesarios para graficar
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Representación gráfica**
#
# Vamos a representar la función $f(x)=x \cos(x)$.

# %%
# 1. Creamos una partición de un intervalo del eje x
x = np.arange(0,10,0.1)      # "Partimos" el intervalo [0,10] en subintervalos de longitud 0.1

# 2. Calculamos la imagen de cada punto
y = x*np.cos(x)

# Pintamos el vector de puntos 'x' respecto al vector de imágenes 'y'
plt.plot(x,y)

# Añadimos etiquetas a los ejes
plt.xlabel('Eje x')
plt.ylabel('Eje y')

# Ponemos un título al gráfico
plt.title('Función $f(x)=x·cos(x)$')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# > ⚠️ **Atención**
# >
# > No mezclar las instrucciones de las bibliotecas `sympy`y `numpy`:
# >
# > * Para operaciones simbólicas y cálculos (límites, derivadas, integrales) `sympy`.
# >
# > * Para representaciones gráficas o trabajo numérico `numpy`.

# %% [markdown]
# 📝 **Prueba tú**:
#
# * Representa gráficamente la función $f(x) = x \cdot \sin(x)$ en el intervalo $[-3\pi, 3\pi]$ utilizando `NumPy` y `Matplotlib`. <br>Personaliza el gráfico final con los siguientes requisitos:
#
#   1.   Dibuja la curva en color verde, con estilo de línea discontinuo (`"--"`).
#   2.   Añade etiquetas a los ejes y pon un título al gráfico.
#   3. Activa la rejilla de fondo (`grid`) para facilitar la lectura

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# **🌟Configuración del lienzo**

# %%
# 1. Partición del eje X (400 puntos entre -2*pi y 2*pi)
x_num = np.linspace(-2*np.pi, 2*np.pi, 400)

# 2. Evaluación numérica de las funciones - Vector de imágenes Y
y1 = np.sin(x_num)
y2 = np.cos(x_num)

# 3. Creación y configuración del lienzo
plt.figure(figsize=(10, 5))              # Tamaño (ancho, alto)

# Representación de los puntos (x,y)
plt.plot(x_num, y1, label=r'$f(x) = \sin(x)$', color='blue', linewidth=2)                  # Etiqueta, color, ancho línea
plt.plot(x_num, y2, label=r"$g(x) = \cos(x)$", color='red', linestyle='--', linewidth=2)   # Etiqueta, color, estilo línea, ancho línea

# 4. Personalización del gráfico
plt.xlim(-2*np.pi, 2*np.pi)        # Límites del eje X
plt.ylim(-1.5, 1.5)                # Límites del eje Y

plt.xlabel('Eje X (Radianes)', fontsize=12)  # Etiqueta del eje X
plt.ylabel('Eje Y', fontsize=12)             # Etiqueta del eje Y
plt.title('Representación de la función seno y coseno', fontsize=14)  # Título

plt.axhline(0, color='black', linewidth=0.8, linestyle='-.')   # Estilo eje X
plt.axvline(0, color='black', linewidth=0.8, linestyle=':')    # Estilo eje Y

plt.grid(True, linestyle='--', alpha=0.6)  # Malla del fondo
plt.legend(loc='upper right', fontsize=12) # Activar leyenda

plt.show()

# %% [markdown]
# ## Actividad Evaluable Individual
# Completa a continuación los cuadros de código que necesites para resolver los ejercicios asignados.

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %%
# ==========================================
# ESCRIBE TU CÓDIGO AQUÍ
# ==========================================

# %% [markdown]
# ## 🚀 Extra: ¿Cómo conectar ambos mundos? (De SymPy a NumPy)

# %% [markdown]
# Es muy habitual querer lo mejor de ambos mundos:
#
# 1.   Modelar o simplificar una **fórmula** compleja algebraicamente con **SymPy**.
# 2.   **Evaluar** esa fórmula en miles de puntos o graficarla a máxima velocidad con **NumPy**.
#
# Si intentas evaluar una expresión de SymPy punto por punto usando `.subs()`, el proceso será excesivamente lento (y costoso). Para evitarlo, existe la función `sp.lambdify()`, que actua como un traductor: toma una expresión simbólica de SymPy y la convierte en una función nativa de NumPy altamente optimizada.

# %% [markdown]
# 💻 **Ejemplo**

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# -------------------------------------------------------------
# PASO 1: Trabajo simbólico en SymPy
# -------------------------------------------------------------
x = sp.Symbol('x')
# Definimos una función matemática simbólica
f_sympy = sp.cos(x)*sp.exp(-x/5)

print("1. Expresión simbólica (SymPy):")
display(f_sympy)

# -------------------------------------------------------------
# PASO 2: El puente -> sp.lambdify()
# -------------------------------------------------------------
# Convertimos la expresión de SymPy en una función ejecutable por NumPy
# Argumentos: (variable_independiente, expresion_sympy, módulo_destino)
f_numpy = sp.lambdify(x, f_sympy, 'numpy')

# -------------------------------------------------------------
# PASO 3: Cálculo masivo y gráfica en NumPy / Matplotlib
# -------------------------------------------------------------
# Generamos 1000 puntos en un instante
x_vals = np.linspace(0, 20, 1000)

# Evaluamos todos los puntos simultáneamente
y_vals = f_numpy(x_vals)

# Graficamos el resultado
plt.figure(figsize=(8, 4))
plt.plot(x_vals, y_vals, label=r'$f(x) = \cos(x) \cdot e^{-x/5}$', color='tab:purple')
plt.title("Evaluación vectorial ultrarrápida tras usar lambdify")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()
